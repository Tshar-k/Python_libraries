# %%
import pandas as pd
df = pd.read_csv("Titanic_dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == int]
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
df.dtypes[df.dtypes == object].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes==object].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes==int].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Sex","Survived","Pclass"]]
# Out:
#         Sex  Survived  Pclass
# 0      male         0       3
# 1    female         1       1
# 2    female         1       3
# 3    female         1       1
# 4      male         0       3
# ..      ...       ...     ...
# 886    male         0       2
# 887  female         1       1
# 888  female         0       3
# 889    male         1       1
# 890    male         0       3
#
# [891 rows x 3 columns]

# %%
df[["Pclass","Survived"]][4:11]
# Out:
#     Pclass  Survived
# 4        3         0
# 5        3         0
# 6        1         0
# 7        3         0
# 8        3         1
# 9        2         1
# 10       3         1

# %%
df["new_col"] =1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        1
# 1      0          PC 17599  71.2833   C85        C        1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1
# 3      0            113803  53.1000  C123        S        1
# ...

# %%
pd.Categorical(df["Survived"])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
pd.Categorical(df["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df[df["Age"] > 18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Age"]<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  new_col
# count  891.000000  891.000000    891.0
# mean     0.381594   32.204208      1.0
# std      0.806057   49.693429      0.0
# min      0.000000    0.000000      1.0
# 25%      0.000000    7.910400      1.0
# 50%      0.000000   14.454200      1.0
# 75%      0.000000   31.000000      1.0
# max      6.000000  512.329200      1.0

# %%
len(df[df["Fare"]<32.204208])
# Out:
# 680

# %%
len(df[df["Fare"]>32.204208])
# Out:
# 211

# %%
df[df["Fare"]<32.204208]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df["Fare"] > 100 ][["Name","Sex","Age"]]
# Out:
#                                                   Name     Sex    Age
# 27                      Fortune, Mr. Charles Alexander    male  19.00
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female    NaN
# 88                          Fortune, Miss. Mabel Helen  female  23.00
# 118                           Baxter, Mr. Quigg Edmond    male  24.00
# 195                               Lurette, Miss. Elise  female  58.00
# 215                            Newell, Miss. Madeleine  female  31.00
# 258                                   Ward, Miss. Anna  female  35.00
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.00
# 269                             Bissette, Miss. Amelia  female  35.00
# 297                       Allison, Miss. Helen Loraine  female   2.00
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00
# 305                     Allison, Master. Hudson Trevor    male   0.92
# ...

# %%
df[df["Sex"] == "male"]['Name']
# Out:
# 0             Braund, Mr. Owen Harris
# 4            Allen, Mr. William Henry
# 5                    Moran, Mr. James
# 6             McCarthy, Mr. Timothy J
# 7      Palsson, Master. Gosta Leonard
#                     ...
# 883     Banfield, Mr. Frederick James
# 884            Sutehall, Mr. Henry Jr
# 886             Montvila, Rev. Juozas
# 889             Behr, Mr. Karl Howell
# 890               Dooley, Mr. Patrick
# Name: Name, Length: 577, dtype: object

# %%
df1 = df[df["Sex"] == 'female']

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 1      0          PC 17599  71.2833   C85        C        1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1
# 3      0            113803  53.1000  C123        S        1
# 8      2            347742  11.1333   NaN        S        1
# ...

# %%
len(df1[df1["Fare"]>32])
# Out:
# 104

# %%
len(df[(df["Sex"]== "female") & (df["Fare"]>32)])
# Out:
# 104

# %%
len(df[(df["Sex"]== "male") & (df["Fare"]>32)])
# Out:
# 107

# %%
len(df[(df["Sex"]== "male") | (df["Fare"]>32)])
# Out:
# 681

# %%
max(df["Fare"])
# Out:
# 512.3292

# %%
df[df["Fare"] == max(df["Fare"])]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df[df["Sex"] == "male"]["Name"]
# Out:
# 0             Braund, Mr. Owen Harris
# 4            Allen, Mr. William Henry
# 5                    Moran, Mr. James
# 6             McCarthy, Mr. Timothy J
# 7      Palsson, Master. Gosta Leonard
#                     ...
# 883     Banfield, Mr. Frederick James
# 884            Sutehall, Mr. Henry Jr
# 886             Montvila, Rev. Juozas
# 889             Behr, Mr. Karl Howell
# 890               Dooley, Mr. Patrick
# Name: Name, Length: 577, dtype: object

# %%
df.iloc[0:20]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df["Name"][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
pd.Series(list(df["Name"][2:7]), index=[1,2,3,4,5])     #indexing is changeds from original to as required
# Out:
# 1                          Heikkinen, Miss. Laina
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3                        Allen, Mr. William Henry
# 4                                Moran, Mr. James
# 5                         McCarthy, Mr. Timothy J
# dtype: object

# %%
pd.Series(list(df["Name"][2:7]), index=[1,"tushar",3,"Kumar",5])
# Out:
# 1                               Heikkinen, Miss. Laina
# tushar    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3                             Allen, Mr. William Henry
# Kumar                                 Moran, Mr. James
# 5                              McCarthy, Mr. Timothy J
# dtype: object

# %%
pd.Series(list(df["Name"][2:7]),index=[i for i in range(1,6)])
# Out:
# 1                          Heikkinen, Miss. Laina
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3                        Allen, Mr. William Henry
# 4                                Moran, Mr. James
# 5                         McCarthy, Mr. Timothy J
# dtype: object

# %%
s = df["Name"][2:7]

# %%
s
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
s1 = df["Name"][48:53]

# %%
s.append(s1)
# Out:
# 2                            Heikkinen, Miss. Laina
# 3      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                          Allen, Mr. William Henry
# 5                                  Moran, Mr. James
# 6                           McCarthy, Mr. Timothy J
# 48                              Samaan, Mr. Youssef
# 49    Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 50                       Panula, Master. Juha Niilo
# 51                     Nosworthy, Mr. Richard Cater
# 52         Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Name: Name, dtype: object

# %%
df.drop(["PassengerId","Survived"],axis =1)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# if we recalled the dataframe again it has the passenger id so to delete it permanently we can use "" inplace = Ture ""

# %%
df.drop(["PassengerId"],axis = 1,inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.drop(3,inplace = True)    # to drop a column

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
#make name column as index
df.set_index("Name")
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
# to do it permanently we have to use inplace = True

# %%
df.set_index("Name",inplace = True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.loc['''Johnston, Miss. Catherine Helen "Carrie"''']
# Out:
# Survived             0
# Pclass               3
# Sex             female
# Age                NaN
# SibSp                1
# Parch                2
# Ticket      W./C. 6607
# Fare             23.45
# Cabin              NaN
# Embarked             S
# new_col              1
# Name: Johnston, Miss. Catherine Helen "Carrie", dtype: object

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
d = {"key1":[1,2,3,4],
     "key2":[3,4,5,6],
     "key3":[4,5,6,7]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     3     4
# 1     2     4     5
# 2     3     5     6
# 3     4     6     7

# %%
df1 = pd.read_excel("Taxonomy.csv.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-100-e9ac6648a99a> in <module>
# ----> 1 df1 = pd.read_excel("Taxonomy.csv.xls")
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna()              #droped all the nan values
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.fillna("tushar")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex     Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0      1
# 2                               Heikkinen, Miss. Laina  female    26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female    27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female    14.0      1
# ...

# %%
df2 = df.groupby("Survived")

# %%
df2.mean()
# Out:
#             Pclass        Age     SibSp     Parch       Fare  new_col
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887      1.0
# 1         1.953079  28.320657  0.472141  0.466276  48.381611      1.0

# %%
df.groupby("Sex").sum()
# Out:
#         Survived  Pclass       Age  SibSp  Parch        Fare  new_col
# Sex
# female       232     677   7251.00    217    204  13913.5628      313
# male         109    1379  13919.17    248    136  14727.2865      577

# %%
df.groupby("Sex").mean()
# Out:
#         Survived    Pclass        Age     SibSp     Parch       Fare  new_col
# Sex
# female  0.741214  2.162939  27.888462  0.693291  0.651757  44.452277      1.0
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893      1.0

# %%
df.groupby("Pclass").mean()
# Out:
#         Survived        Age     SibSp     Parch       Fare  new_col
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128      1.0
# 2       0.472826  29.877630  0.402174  0.380435  20.662183      1.0
# 3       0.242363  25.140620  0.615071  0.393075  13.675550      1.0

# %%
df_new = df.groupby("Pclass").sum()

# %%
df_new.T
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7076.4200  5168.8300  8924.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18124.3125  3801.8417  6714.6951
# new_col     215.0000   184.0000   491.0000

# %%
d1 = {"key1":[1,2,3,4],
     "key2":[3,4,5,6],
     "key3":[4,5,6,7]}

# %%
d2 = {"key1":[1,2,3,4],
     "key5":[3,4,5,6],
     "key6":[4,5,6,7]}

# %%
data1 = pd.DataFrame(d1)

# %%
data2 = pd.DataFrame(d2)

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key5  key6
# 0     1     3     4     3     4
# 1     2     4     5     4     5
# 2     3     5     6     5     6
# 3     4     6     7     6     7

# %%
data3 = {"a" : [1,2,3,4],
         "b" : [5,6,7,8],
         "c" : ["tushar","kumar","manjeet","saurabh"]}

# %%
df4 = pd.DataFrame(data3)

# %%
df4.set_index("c",inplace = True)

# %%
df4
# Out:
#          a  b
# c
# tushar   1  5
# kumar    2  6
# manjeet  3  7
# saurabh  4  8

# %%
df4 = df4.reset_index()

# %%
df4
# Out:
#          c  a  b
# 0   tushar  1  5
# 1    kumar  2  6
# 2  manjeet  3  7
# 3  saurabh  4  8

# %%
df4.reindex(['a','b','c'],axis =1)
# Out:
#    a  b        c
# 0  1  5   tushar
# 1  2  6    kumar
# 2  3  7  manjeet
# 3  4  8  saurabh

# %%
for i in df4.iterrows():
  print(i)
# Out:
# (0, c    tushar
# a         1
# b         5
# Name: 0, dtype: object)
# (1, c    kumar
# a        2
# b        6
# Name: 1, dtype: object)
# (2, c    manjeet
# a          3
# b          7
# Name: 2, dtype: object)
# (3, c    saurabh
# a          4
# b          8
# Name: 3, dtype: object)
